# %%
from network import Neuron, Layer, MLP, Experiment
from core import Value, draw_dot, trace

# %%
x = [3.0,4.0,5.0]
net = MLP(3,[4,4,1])
y = net(x)

# %%
y
# Out:
# Value(data=1.1908061759432385, grad=0)

# %%
net = Experiment(3,[4,4,1])
xs = [[3.0,4.0,4.0],[5.0,2.0,4.0],[1.0,-1.0,2.0],[3.6,1.3,5.6]]
ys = [1.0,2.0,3.0,4.0]

# %%
net.model.layers[0].neurons[0].w[0].grad
# Out:
# 0

# %%
net(xs,ys,num_epochs=100)
# Out:
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# [1.0, 2.0, 3.0, 4.0]
# [Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0), Value(data=0.0, grad=0)]
# ...
